# %%
import numpy as np
import matplotlib.pyplot as plt
from iminuit import Minuit
from iminuit.cost import ExtendedBinnedNLL
from scipy.stats import norm

raw_data = np.loadtxt(r"C:\Users\lenovo\Desktop\AlfaRuth24-25_S1\strato_morto\strato_morto_num2.dat")

data1 = []

for i in range(len(raw_data)):
    for j in range(int(raw_data[i])):
        data1.append(i)

data = np.array(data1)

signal = []


for i in range(len(data)):
    if data[i] > 3000 and data[i] < 5500: signal.append(data[i])

plt.hist(signal, bins=100)
plt.show()
